# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/Users/rshah181/Desktop/AMADEUS/NIFTY100/MRF.csv").fillna(0)
df['Open'] = df['close']

# %%
df['datetime'] = df['datetime'].apply(lambda x : datetime.strptime(x[:-6], '%Y-%m-%d %H:%M:%S'))
df['date'] = df['date'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d'))

df = df.set_index('datetime')

# df = df[(df['date'] > datetime.strptime('2019-01-01', '%Y-%m-%d'))]

# %%
df
# Out:
#                 open      high       low     close  volume      time  \
# datetime
# 2005-01-03   2450.00   2542.55   2431.00   2542.55    5572  00:00:00
# 2005-01-04   2575.00   2598.00   2530.30   2550.05    3620  00:00:00
# 2005-01-05   2540.00   2599.00   2422.55   2577.30    8347  00:00:00
# 2005-01-06   2535.00   2560.00   2470.00   2512.55    2831  00:00:00
# 2005-01-07   2545.00   2555.00   2480.00   2498.95    5054  00:00:00
# ...              ...       ...       ...       ...     ...       ...
# 2020-03-02  66891.00  67595.90  65551.00  65976.30    6419  00:00:00
# 2020-03-03  66799.00  68558.35  65600.00  67740.70    8202  00:00:00
# 2020-03-04  67270.00  67698.80  66100.00  67053.35    8187  00:00:00
# 2020-03-05  67300.05  68169.90  66809.50  67325.15    5745  00:00:00
# 2020-03-06  66389.00  66500.20  63858.55  66348.15    9851  00:00:00
#
#                  date      Open
# datetime
# 2005-01-03 2005-01-03   2542.55
# 2005-01-04 2005-01-04   2550.05
# ...

# %%
# %%timeit

# df['Open'] = df['open']

# %%
# data = pd.read_pickle("/Users/rshah181/Desktop/AMADEUS/resample_testing.pkl")
# # data2 = data.resample('15Min', closed='right').last()
# df=data
# df['Open'] = df['open']

# %%
df
# Out:
#                 open      high       low     close  volume      time  \
# datetime
# 2005-01-03   2450.00   2542.55   2431.00   2542.55    5572  00:00:00
# 2005-01-04   2575.00   2598.00   2530.30   2550.05    3620  00:00:00
# 2005-01-05   2540.00   2599.00   2422.55   2577.30    8347  00:00:00
# 2005-01-06   2535.00   2560.00   2470.00   2512.55    2831  00:00:00
# 2005-01-07   2545.00   2555.00   2480.00   2498.95    5054  00:00:00
# ...              ...       ...       ...       ...     ...       ...
# 2020-03-02  66891.00  67595.90  65551.00  65976.30    6419  00:00:00
# 2020-03-03  66799.00  68558.35  65600.00  67740.70    8202  00:00:00
# 2020-03-04  67270.00  67698.80  66100.00  67053.35    8187  00:00:00
# 2020-03-05  67300.05  68169.90  66809.50  67325.15    5745  00:00:00
# 2020-03-06  66389.00  66500.20  63858.55  66348.15    9851  00:00:00
#
#                  date      Open
# datetime
# 2005-01-03 2005-01-03   2542.55
# 2005-01-04 2005-01-04   2550.05
# ...

# %%
pd.DataFrame({'open' :df['Open'], 'lag_open' :df['Open'].shift(5)}).corr()
# Out:
#               open  lag_open
# open      1.000000  0.998689
# lag_open  0.998689  1.000000

# %%
plt.figure(figsize=(10,10))
lag_plot(df['Open'], lag=5)
plt.title('Microsoft Autocorrelation plot')
# Out:
# Text(0.5, 1.0, 'Microsoft Autocorrelation plot')

# %%
train_data, test_data = df[0:int(len(df)*0.8)], df[int(len(df)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Microsoft Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(df['Open'], 'blue', label='Training Data')
plt.plot(test_data['Open'], 'green', label='Testing Data')
plt.legend()

# %%
def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

# %%
train_ar = train_data['Open'].values
test_ar = test_data['Open'].values

# %%
history = [x for x in train_ar]

# %%
predictions = list()

# %%
test_ar
# Out:
# array([51499.05, 51437.15, 51835.05, 52819.4 , 51951.6 , 52072.85,
#        52375.55, 52167.9 , 51527.8 , 52031.35, 52220.3 , 52983.9 ,
#        56836.6 , 56425.55, 55427.85, 56019.35, 58045.15, 57849.2 ,
#        59507.1 , 59308.8 , 59888.5 , 58315.35, 59578.45, 59300.  ,
#        60954.45, 60993.55, 60685.45, 61104.85, 61036.15, 60767.45,
#        62063.4 , 60527.1 , 60566.55, 61948.55, 62596.1 , 63089.25,
#        63500.8 , 63283.7 , 63995.35, 66566.25, 68850.55, 68495.6 ,
#        67909.2 , 68372.55, 68639.9 , 67022.55, 68135.95, 67634.1 ,
#        66683.05, 65936.7 , 66055.95, 65455.15, 65823.4 , 66093.35,
#        68054.7 , 66960.4 , 65876.65, 64254.05, 63976.15, 62519.7 ,
#        63820.  , 65401.8 , 64937.95, 65398.1 , 65559.1 , 68217.3 ,
#        67715.95, 68334.25, 68820.5 , 68985.95, 71129.65, 72901.25,
#        73331.6 , 72369.3 , 71102.15, 72847.45, 71978.1 , 71760.2 ,
#        71656.2 , 71709.1 , 70975.9 , 69935.8 , 68585.55, 68915.8 ,
# ...

# %%
model = ARIMA(history, order=(5,1,0))
model_fit = model.fit(disp=0)
output = model_fit.forecast(750)
yhat = output[0]

# %%
yhat
# Out:
# array([49802.5028926 , 49790.74473015, 49785.92196138, 49809.22195634,
#        49815.0592885 , 49829.84260824, 49846.1625268 , 49860.69685564,
#        49876.70079106, 49892.35458519, 49907.97867862, 49923.77913658,
#        49939.49484572, 49955.23837914, 49970.99059388, 49986.73214188,
#        50002.48036151, 50018.22736012, 50033.97379037, 50049.72109179,
#        50065.46799426, 50081.21498239, 50096.9620306 , 50112.70902113,
#        50128.45604013, 50144.20305577, 50159.95006706, 50175.69708267,
#        50191.44409654, 50207.19111059, 50222.938125  , 50238.68513913,
#        50254.43215337, 50270.17916761, 50285.92618182, 50301.67319606,
#        50317.42021028, 50333.16722451, 50348.91423874, 50364.66125296,
#        50380.40826719, 50396.15528142, 50411.90229565, 50427.64930987,
#        50443.3963241 , 50459.14333833, 50474.89035256, 50490.63736678,
#        50506.38438101, 50522.13139524, 50537.87840946, 50553.62542369,
# ...

# %%
predictions = list(yhat)

history = list(test_ar)

# %%
for t in range(len(test_ar)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = yhat
    history.append(obs)

# %%
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# Testing Mean Squared Error: 167706351.355
# Symmetric mean absolute percentage error: 17.137

# %%
train_ar = train_data['Open'].values
test_ar = test_data['Open'].values
history = list(train_ar)

predictions = list()
for t in range(750):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    history.append(yhat)
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# Testing Mean Squared Error: 167706351.355
# Symmetric mean absolute percentage error: 17.137

# %%
predictions
# Out:
# [array([49802.5028926]),
#  array([49790.75041757]),
#  array([49785.92538642]),
#  array([49809.21653133]),
#  array([49815.04728862]),
#  array([49829.8206495]),
#  array([49846.12997516]),
#  array([49860.65405746]),
#  array([49876.64700064]),
#  array([49892.28991926])]

# %%
history
# Out:
# [2542.55,
#  2550.05,
#  2577.3,
#  2512.55,
#  2498.95,
#  2623.9,
#  2530.2,
#  2473.05,
#  2498.8,
#  2452.65,
#  2399.85,
#  2392.9,
#  2389.7,
#  2398.2,
#  2347.7,
#  2345.2,
#  2321.4,
#  2389.8,
#  2416.05,
#  2431.9,
#  2411.8,
#  2414.15,
#  2514.7,
#  2598.05,
#  2638.45,
#  2725.0,
#  2740.1,
#  2719.55,
#  2767.3,
#  2690.55,
#  2616.65,
#  2608.95,
#  2685.35,
#  2683.4,
#  2682.25,
#  2642.8,
#  2637.3,
#  2696.05,
#  2799.45,
#  2866.3,
#  2853.3,
#  2880.3,
#  3072.6,
#  3099.95,
#  3110.5,
#  3106.45,
#  2997.8,
#  2986.6,
#  2966.2,
#  3029.6,
#  3053.35,
#  3022.75,
#  2945.4,
#  2976.4,
#  2950.2,
#  2929.4,
#  2927.35,
#  2940.85,
#  2802.95,
#  2898.5,
#  2948.05,
#  2912.75,
#  2881.4,
#  2768.35,
#  2827.15,
#  2793.1,
#  2759.8,
#  2735.7,
#  2767.0,
#  2761.65,
#  2704.0,
#  2684.95,
#  2705.15,
#  2704.45,
#  2698.7,
#  2710.2,
#  2750.8,
#  2743.35,
#  2716.65,
#  2746.65,
#  2649.95,
#  2570.1,
#  2500.65,
#  2501.3,
#  2511.25,
#  2506.9,
#  2602.7,
# ...

# %%
'''train_ar = train_data['Open'].values
test_ar = test_data['Open'].values
history = list(train_ar)

predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)'''
# Out:
# Testing Mean Squared Error: 925559.200
# Symmetric mean absolute percentage error: 11.871

# %%
df2 = pd.DataFrame(predictions, test_data['Open'])

# %%
df2 = df2.reset_index()

# %%
df2.columns = ['actual', 'predicted']

# %%
df2['diff'] = df2['actual'] - df2['predicted']

# %%
df2.tail(20)
# Out:
#        actual     predicted         diff
# 730  70960.45  71505.390577  -544.940577
# 731  73247.90  70936.089226  2311.810774
# 732  71381.70  73476.489723 -2094.789723
# 733  71675.95  71305.900827   370.049173
# 734  71525.15  71666.659285  -141.509285
# 735  71799.20  71553.323673   245.876327
# 736  71299.80  71887.850412  -588.050412
# 737  69693.60  71251.934256 -1558.334256
# 738  69959.30  69645.383291   313.916709
# 739  70789.50  70028.984478   760.515522
# 740  68874.70  70895.983268 -2021.283268
# 741  69133.45  68775.935550   357.514450
# 742  68140.00  69140.804315 -1000.804315
# 743  67559.45  68161.394551  -601.944551
# 744  66393.20  67593.694515 -1200.494515
# 745  65976.30  66345.222837  -368.922837
# 746  67740.70  66018.639330  1722.060670
# 747  67053.35  67854.199275  -800.849275
# 748  67325.15  67007.249581   317.900419
# 749  66348.15  67293.602030  -945.452030

# %%
plt.figure(figsize=(12,7))
plt.plot(df['Open'], 'green', color='blue', label='Training Data')
plt.plot(test_data[:10].index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data[:10].index, test_data[:10]['Open'], color='red', label='Actual Price')
plt.title('Microsoft Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-179c54d02f37> in <module>
#       2 plt.plot(df['Open'], 'green', color='blue', label='Training Data')
#       3 plt.plot(test_data[:10].index, predictions, color='green', marker='o', linestyle='dashed',
# ----> 4          label='Predicted Price')
#       5 plt.plot(test_data[:10].index, test_data[:10]['Open'], color='red', label='Actual Price')
#       6 plt.title('Microsoft Prices Prediction')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
plt.figure(figsize=(15,10))
plt.plot(test_data[:10].index, predictions, color='green', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_data[:10].index, test_data[:10]['Open'], color='red', label='Actual Price')
plt.legend()
plt.title('Microsoft Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()

# %%
plt.figure(figsize=(12,7))
plt.plot(df['Open'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
plt.title('Microsoft Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()

# %%
plt.figure(figsize=(12,7))
plt.plot(test_data.index[10:30], predictions[10:30], color='green', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_data.index[10:30], test_data[10:30]['Open'], color='red', label='Actual Price')
plt.legend()
plt.title('Microsoft Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()

# %% [markdown]
# ***
